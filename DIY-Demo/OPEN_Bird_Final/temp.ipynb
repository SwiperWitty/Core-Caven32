# %%
import os
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Witty-Q\AppData\Local\Temp\ipykernel_28740\2117938815.py:2: SyntaxWarning: invalid escape sequence '\S'
#   mk = os.walk('E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src')

# %%
mk = os.walk('E:\\Sea_of_Stars\\Software\\Core-Caven32\\DIY-Demo\\OPEN_Bird_Final\\bird_gui\\lvgl\\src')
f = open("E:\\Sea_of_Stars\\Software\\Core-Caven32\\DIY-Demo\\OPEN_Bird_Final\\temp.txt", 'w')
for root, dir, files in mk:
    for file in files:
        file_str = str(os.path.join(root, file))
        if file_str.endswith(".c"):
            print(file_str)
            f.write(file_str)

f.close()
# Out:
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_disp.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_event.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_group.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_indev.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_indev_scroll.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_obj.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_obj_class.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_obj_draw.c
# E:\Sea_of_Stars\Software\Core-Caven32\DIY-Demo\OPEN_Bird_Final\bird_gui\lvgl\src\core\lv_obj_pos.c
# ...

# %%
# f = open('E:\\Sea_of_Stars\\Software\\Core-Caven32\\DIY-Demo\\OPEN_Bird_Final\\temp.txt', 'r')
import os
file_congf = '''<File>
                    <FileName>{}</FileName>
                    <FileType>1</FileType>
                    <FilePath>{}</FilePath>
                </File>
'''


with open('E:\\Sea_of_Stars\\Software\\Core-Caven32\\DIY-Demo\\OPEN_Bird_Final\\temp.txt', 'r') as f:
    for line in f.readlines():
        print(file_congf.format(os.path.basename(line), line) )
        with open('E:\\Sea_of_Stars\\Software\\Core-Caven32\\DIY-Demo\\OPEN_Bird_Final\\fil.txt', 'a') as fa:
            fa.write(file_congf.format(os.path.basename(line)[:-1], line[:-1]))
# Out:
# <File>
#                     <FileName>lv_disp.c
# </FileName>
#                     <FileType>1</FileType>
#                     <FilePath>..\bird_gui\lvgl\src\core\lv_disp.c
# </FilePath>
#                 </File>
#
# <File>
#                     <FileName>lv_event.c
# </FileName>
#                     <FileType>1</FileType>
#                     <FilePath>..\bird_gui\lvgl\src\core\lv_event.c
# </FilePath>
#                 </File>
#
# <File>
#                     <FileName>lv_group.c
# </FileName>
#                     <FileType>1</FileType>
#                     <FilePath>..\bird_gui\lvgl\src\core\lv_group.c
# </FilePath>
#                 </File>
#
# <File>
#                     <FileName>lv_indev.c
# </FileName>
#                     <FileType>1</FileType>
#                     <FilePath>..\bird_gui\lvgl\src\core\lv_indev.c
# </FilePath>
#                 </File>
#
# <File>
#                     <FileName>lv_indev_scroll.c
# </FileName>
# ...
